# %%
print ("help")
# Out:
# help

# %%
x = 5
y = 10
print(x + y)
# Out:
# 15

# %%
hello = "Hello, World!"
print(hello)
# Out:
# Hello, World!

# %%
if x < y:
    print("x is less than y")
# Out:
# x is less than y
